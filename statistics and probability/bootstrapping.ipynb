# %%
import pandas as pd
import numpy as np
 
 
#moview reviews
df=pd.read_csv('../7282_1.csv')
 
#sample 
s=df.sample(500,random_state=7)
 
s.head(2)
# Out:
#                       address categories        city country   latitude  \
# 17927            Via Regina 1     Hotels     Griante      US  45.987791
# 17330  24977 Northwestern Hwy     Hotels  Southfield      US  42.472016
#
#        longitude                    name postalCode province  \
# 17927   9.234449  Grand Hotel Cadenabbia      22011       CO
# 17330 -83.241718          Comfort Suites      48076       MI
#
#                reviews.date     reviews.dateAdded  reviews.doRecommend  \
# 17927  2013-11-08T00:00:00Z  2016-10-29T03:35:31Z                  NaN
# 17330  2015-08-25T00:00:00Z  2016-11-15T21:04:32Z                  NaN
#
#        reviews.id  reviews.rating  \
# 17927         NaN             5.0
# 17330         NaN             5.0
#
#                                             reviews.text  \
# 17927  We stayed here recently for four nights. The h...
# 17330  Very comfortable and clean hotel. Staff was ve...
#
#                                  reviews.title reviews.userCity  \
# 17927  Lakefront with garden patio, good value              NaN
# 17330                         Would stay again              NaN
#
#       reviews.username reviews.userProvince
# 17927            Brett                  NaN
# 17330            Rocky                  NaN

# %%
#bootstrapping
bootstrap=pd.DataFrame({'mean_rating':[s.sample(500,replace=True)['reviews.rating'].mean() for i in range(0,1000)]})
bootstrap
# Out:
#      mean_rating
# 0       3.693033
# 1       3.698129
# 2       3.588454
# 3       3.714344
# 4       3.618200
# ..           ...
# 995     3.752893
# 996     3.680777
# 997     3.720859
# 998     3.714784
# 999     3.660164
#
# [1000 rows x 1 columns]

# %%
(bootstrap['mean_rating'].quantile(0.025),bootstrap['mean_rating'].quantile(0.975))
# Out:
# (3.552608024691358, 3.7991989899829584)
